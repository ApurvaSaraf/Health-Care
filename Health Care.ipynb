# %% [markdown]
# ## Health Care.

# %%
## Import the required libraries:
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Read the books dataset and explore it
Health=pd.read_excel(r'C:\Users\mitta\Downloads\1645792390_cep1_dataset.xlsx')
Health
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Check the data type of data
Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# Check for null values
Health.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
## Get a preliminary statistical summary of the data 
Health.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
## Check whether data is balanced or not
b=Health.target.value_counts()
plt.bar(b.index,b.values)
# Out:
# <BarContainer object of 2 artists>

# %%
X=Health.drop('target',axis=1)
X
y=Health['target']

# %%
p=X.sex.value_counts()  # 1 = male; 0 = female
p
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
## explore the measures of central tendencies and spread of the data
for i in X.columns:
    plt.hist(X[i])
    plt.xlabel(i)
    plt.show()

# %%
## explore the measures of central tendencies and spread of the data
for i in X.columns:
    sns.countplot(X[i])
    plt.xlabel(i)
    plt.show()

# %%
Age=X['age'].value_counts()
Age.values
# Out:
# array([19, 17, 16, 14, 13, 12, 11, 11, 11, 11, 10, 10,  9,  9,  8,  8,  8,
#         8,  8,  8,  8,  7,  7,  7,  7,  5,  5,  4,  4,  4,  4,  3,  3,  3,
#         3,  2,  2,  1,  1,  1,  1], dtype=int64)

# %%
plt.bar(Age.index,Age.values)
# Out:
# <BarContainer object of 41 artists>

# %%
##Study the occurrence of CVD across the Age category
pd.set_option('display.max_rows', 300)
Health.groupby(['target','age']).size()
# Out:
# target  age
# 0       35      2
#         38      1
#         39      1
#         40      2
#         41      1
#         42      1
#         43      3
#         44      3
#         45      2
#         46      3
#         47      2
#         48      3
#         49      2
#         50      3
#         51      3
#         52      4
#         53      2
#         54      6
#         55      5
#         56      6
#         57     10
#         58     12
#         59      9
#         60      8
#         61      7
#         62      7
#         63      6
#         64      4
#         65      4
#         66      3
#         67      6
#         68      2
#         69      1
#         70      3
#         77      1
# 1       29      1
#         34      2
#         35      2
#         37      2
#         38      2
#         39      3
#         40      1
#         41      9
#         42      7
#         43      5
#         44      8
#         45      6
#         46      4
#         47      3
# ...

# %%
##Study the composition of all patients with respect to the Sex category
Health.groupby(['target','sex']).size()  ## 1 = male; 0 = female
# Out:
# target  sex
# 0       0       24
#         1      114
# 1       0       72
#         1       93
# dtype: int64

# %%
## Study if one can detect heart attacks based on anomalies in the resting blood pressure (trestbps) of a patient
plt.plot(Health['trestbps'],Health['target'])

# %%
plt.hist(X.age,bins=20)
# Out:
# (array([ 1.,  0.,  6.,  5.,  7., 26., 19., 19., 12., 25., 32., 28., 44.,
#         19., 19., 24.,  7.,  7.,  1.,  2.]),
#  array([29. , 31.4, 33.8, 36.2, 38.6, 41. , 43.4, 45.8, 48.2, 50.6, 53. ,
#         55.4, 57.8, 60.2, 62.6, 65. , 67.4, 69.8, 72.2, 74.6, 77. ]),
#  <BarContainer object of 20 artists>)

# %%
import seaborn as sns
for i in X.columns:
    sns.boxplot(x=X[i])
    plt.show()

# %%
# Removal of outliers
Health=Health.loc[Health['trestbps']<160]
Health=Health.loc[Health['chol']<350]
Health=Health.loc[Health['oldpeak']<4]
Health.shape
# Out:
# (266, 14)

# %%
## Use a pair plot to understand the relationship between all the given variables
plt.figure(figsize=(16,9))
sns.pairplot(Health)

# %%
plt.figure(figsize=(15,8))
cor=Health.corr()
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data=scaler.fit_transform(X)
data
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292, ..., -2.27457861,
#         -0.71442887, -2.14887271],
#        [-1.91531289,  0.68100522,  1.00257707, ..., -2.27457861,
#         -0.71442887, -0.51292188],
#        [-1.47415758, -1.46841752,  0.03203122, ...,  0.97635214,
#         -0.71442887, -0.51292188],
#        ...,
#        [ 1.50364073,  0.68100522, -0.93851463, ..., -0.64911323,
#          1.24459328,  1.12302895],
#        [ 0.29046364,  0.68100522, -0.93851463, ..., -0.64911323,
#          0.26508221,  1.12302895],
#        [ 0.29046364, -1.46841752,  0.03203122, ..., -0.64911323,
#          0.26508221, -0.51292188]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,y,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
Lr=LogisticRegression()

# %%
model=Lr.fit(X_train,y_train)

# %%
y_pre=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(y_pre,y_test))
print(accuracy_score(y_pre,y_test)*100)
# Out:
# [[24  8]
#  [11 33]]
# 75.0

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pr=clf.predict(X_test)
print(confusion_matrix(y_pr,y_test))
print(accuracy_score(y_pr,y_test)*100)
# Out:
# [[27 13]
#  [ 8 28]]
# 72.36842105263158

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train,y_train)
y_pr=clf.predict(X_test)
print(confusion_matrix(y_pr,y_test))
print(accuracy_score(y_pr,y_test)*100)
# Out:
# [[25  6]
#  [10 35]]
# 78.94736842105263
